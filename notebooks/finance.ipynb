# %%
import sys
sys.path.append(os.path.abspath(os.path.join('..', 'scripts')))
from stock_analysis_talib import load_and_process_stock_data, visualize_stock_data
data_folder = '../data/yfinance_data/'
stock_data = load_and_process_stock_data(data_folder)
visualize_stock_data(stock_data)
# Out:
# Applying indicators to AAPL...
# Applying indicators to AMZN...
# Applying indicators to GOOG...
# Applying indicators to META...
# Applying indicators to MSFT...
# Applying indicators to NVDA...
# Applying indicators to TSLA...
#
# AAPL data with indicators:
#             Date       Close      SMA_10      SMA_20        RSI      MACD  \
# 10993 2024-07-24  218.539993  227.220999  224.228500  48.687742  4.662717
# 10994 2024-07-25  217.490005  226.212999  224.440500  47.386437  3.748082
# 10995 2024-07-26  217.960007  224.955000  224.633500  48.055700  3.026267
# 10996 2024-07-29  218.240005  223.339001  225.014500  48.476184  2.448591
# 10997 2024-07-30  218.800003  221.737001  225.117001  49.359115  2.012764
#
#        MACD_Signal  MACD_Hist
# 10993     6.678882  -2.016164
# 10994     6.092722  -2.344640
# 10995     5.479431  -2.453164
# 10996     4.873263  -2.424672
# 10997     4.301163  -2.288399
# AMZN data with indicators:
# ...

# %%
import sys
sys.path.append(os.path.abspath(os.path.join('..', 'scripts')))
from stock_analysis_pynance import load_and_process_stock_data, visualize_stock_data
data_folder = '../data/yfinance_data/'
stock_data = load_and_process_stock_data(data_folder)
visualize_stock_data(stock_data)
# Out:
# Applying indicators to AAPL...
# Applying indicators to AMZN...
# Applying indicators to GOOG...
# Applying indicators to META...
# Applying indicators to MSFT...
# Applying indicators to NVDA...
# Applying indicators to TSLA...
#
# AAPL data with indicators:
#             Date       Close         SMA         EMA  Volatility
# 10993 2024-07-24  218.539993  224.228500  222.376929    6.966712
# 10994 2024-07-25  217.490005  224.440500  221.911508    6.673385
# 10995 2024-07-26  217.960007  224.633500  221.535174    6.409177
# 10996 2024-07-29  218.240005  225.014500  221.221349    5.721927
# 10997 2024-07-30  218.800003  225.117001  220.990744    5.582758
# AMZN data with indicators:
#            Date       Close       SMA         EMA  Volatility
# 6841 2024-07-24  180.830002  192.8900  189.093555    6.497821
# 6842 2024-07-25  179.850006  192.2020  188.213217    7.116578
# 6843 2024-07-26  182.500000  191.4345  187.669101    7.300742
# ...
